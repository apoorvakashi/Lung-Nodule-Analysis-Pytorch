# %%
# %matplotlib inline
import copy
import numpy as np
import matplotlib.pyplot as plt

# %%
from combining_data.combining_data import getCandidatesList, getCt, LunaDataset
candidates_list = getCandidatesList(reqOnDisk = True)

# %%
from utill.util import xyz2irc
candidates_list[0]
# Out:
# CandidateTuple(isNodule=True, diameter_mm=25.23320204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(63.4740118048, 73.9174523314, -213.736128767))

# %%
from combining_data.visualization import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2022-05-09 13:27:07,697 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C333A0>: 56938 training samples
# 2022-05-09 13:27:07,698 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C333A0>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio

# %%
augmentation_dict = {}
augmentation_list = [
    ('None', {}),
    ('flip', {'flip': True}),
    ('offset', {'offset': 0.1}),
    ('scale', {'scale': 0.2}),
    ('rotate', {'rotate': True}),
    ('noise', {'noise': 25.0}),    
]
ds_list = [
    LunaDataset(sortby_str='label_and_size', augmen_dict=augmentation_dict) 
    for title_str, augmentation_dict in augmentation_list
]

all_dict = {}
for title_str, augmentation_dict in augmentation_list:
    all_dict.update(augmentation_dict)
all_ds = LunaDataset(sortby_str='label_and_size', augmen_dict=all_dict)

augmentation_list.extend([('All', augmentation_dict)] * 3)
ds_list.extend([all_ds] * 3)
# Out:
# 2022-05-09 13:27:07,723 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B79186E190>: 56938 training samples
# 2022-05-09 13:27:07,724 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B79186E190>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,732 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33DC0>: 56938 training samples
# 2022-05-09 13:27:07,734 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33DC0>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,741 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33D90>: 56938 training samples
# 2022-05-09 13:27:07,742 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33D90>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,748 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33DF0>: 56938 training samples
# 2022-05-09 13:27:07,749 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C33DF0>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,757 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C22370>: 56938 training samples
# 2022-05-09 13:27:07,757 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7F7C22370>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,763 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7800B1FA0>: 56938 training samples
# 2022-05-09 13:27:07,763 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B7800B1FA0>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio
# 2022-05-09 13:27:07,770 INFO     pid:29172 combining_data.combining_data:287:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B79186E1C0>: 56938 training samples
# 2022-05-09 13:27:07,771 INFO     pid:29172 combining_data.combining_data:293:__init__ <combining_data.combining_data.LunaDataset object at 0x000001B79186E1C0>: 56938 training samples, 56816 neg, 122 pos, unbalanced ratio

# %%
sample_ndx = 100
# sample_ndx = 154
# sample_ndx = 155


sample_tup = all_ds[sample_ndx]
print(sample_tup[0].shape, sample_tup[1:])

fig = plt.figure(figsize=(30, 30))

clim=(-1000.0, 300)

for i, ((title_str, _), ds) in enumerate(zip(augmentation_list, ds_list)):
    sample_tup = ds[sample_ndx]
    subplot = fig.add_subplot(3, 3, i+1)
    subplot.set_title(title_str, fontsize=30)
    for label in (subplot.get_xticklabels() + subplot.get_yticklabels()):
        label.set_fontsize(20)
    plt.imshow(sample_tup[0][0][16], clim=clim, cmap='gray')
# Out:
# torch.Size([1, 32, 48, 48]) (tensor([1, 0]), '1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707182900091062408058', tensor([ 60, 242, 422]))
# <img src="data:image/png;base64,..." width="2160">
